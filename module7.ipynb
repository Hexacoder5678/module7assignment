# %% [markdown]
# QUES-1->Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
# navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
# items must change their text color on hover?

# %% [markdown]
# ANS=><!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Navigation Bar</title>
#     <link rel="stylesheet" href="module7.css">
# </head>
# <body>
#     <nav class="navbar">
#         <ul class="nav-links">
#             <li><a href="#">home</a></li>
#             <li><a href="#">about</a></li>
#             <li><a href="#">contact</a></li>
#             <li><a href="#">block</a></li>
#             <li><a href="#">login</a></li>
#         </ul>
#     </nav>
# </body>
# </html>
# <!-- css code is below:<br><br>
#
#
# *{
#     margin:0;
#     padding:0;
#     box-sizing:border-box;
# }
#
# .navbar{
#     background-color:burlywood;
#     padding:20px;
# }
#
# .nav-links{
#     list-style: none;
#     display:flex;
#     justify-content: center;
#     gap:40px;
# }
#
# .nav-links li a{
#     text-decoration: none;
#     color:white;
#     font-size:18px;
#     padding:8px 12px;
#     transition: color 0.3s ease;
# }
#
# .nav-links li a:hover{
#     color:#ff6347;
# }-->

# %% [markdown]
# QUES-2->Create a div centered with an image and paragraph similar to the image mentioned below?

# %% [markdown]
# ANS 2=>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>CENTER DIV WITH IMAGE</title>
#     <link rel="stylesheet" href="module7.css">
# </head>
# <body>
#     <div class="centered-box">
#         <img src="https://media.licdn.com/dms/image/sync/v2/D5627AQHT9jBvQb73mQ/articleshare-shrink_800/articleshare-shrink_800/0/1739028147236?e=2147483647&v=beta&t=fjluhKnnh-Vt-bcSqNPtdMydBAO7II5Sk1WrXHolJms" alt="SAMPLE IMAGE">
#         <p>THIS IS THE SAMPLE PARAGRAPH BELOW THE IMAGE.IT IS CENTERED ALONG WITH THE IMAGE INSIDE THE BOX</p>
#     </div>
# </body>
# </html>
# <!-- below is the css code
# *{
#     margin:0;
#     padding: 0;
#     box-sizing: border-box;
# }
# .centered-box{
#     width:350px;
#     background-color: #f9f9f9;
#     padding:20px;
#     margin:50px auto;
#     text-align: center;
#     box-shadow: 0 4px  8px rgba(0,0,0,0.1);
#     border-radius: 10px;
# }
# .centered-box img{
#     width:100%;
#     border-radius: 8px;
#     margin-bottom:  15pxx;
# }
# .centered-box p{
#     font-size:16px;
#     color:#333;
#     line-height:1.5;
# }-->

# %% [markdown]
# QUES-3->Create a navigation bar similar to question 1. For each navigation item, use a different border style?

# %% [markdown]
# ANS-3=>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>NAVIGATION BAR</title>
#     <link rel="stylesheet" href="module7.css">
# </head>
# <body>
#     <nav class="navbar">
#         <ul>
#             <li class="nav-item solid"><a href="#">home</a></li>
#             <li class="nav-item dotted"><a href="#">about</a></li>
#             <li class="nav-item dashed"><a href="#">services</a></li>
#             <li class="nav-item double"><a href="#">contact</a></li>
#         </ul>
#     </nav>
# </body>
# </html>
# <!-- below is the css code
#
# *{
#     margin: 0;
#     padding:0;
#     box-sizing:border-box;
# }
# .navbar{
#     background-color: #ff6347;
#     padding:15px 0;
# }
# .navbar ul{
#     list-style: none;
#     display: flex;
#     justify-content: center;
#     gap:20px;
# }
# .nav-item a{
#     text-decoration: none;
#     color:white;
#     padding:10 px 20 px;
#     display:inline-block;
#     transition: color 0.3s ease;
# }
# .nav-item a:hover{
#     color:#ff9800;
# }
# .solid a{
#     border:2px solid white;
# }
# .dotted a{
#     border:2 px dotted white;
# }
# .double a{
#     border:4 px double white;
# }
# .dashed a{
#     border: 2px dashed white;
# }
# */

# %% [markdown]
# QUES-4->Create a simple webpage with an image and make the image circular using border-radius?
# <br><br>
# ANS=>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Circular Image</title>
#     <style>
#           body {
#       display: flex;
#       flex-direction: column;
#       align-items: center;
#       justify-content: center;
#       height: 100vh;
#       margin: 0;
#       font-family: Arial, sans-serif;
#     }
#         .circular-image{
#             width:200px;
#             height:200px;
#             border-radius: 20%;
#         }
#     </style>
# </head>
# <body>
#     <h2>My Circular Image</h2>
#     <img src="https://s3.ap-south-1.amazonaws.com/cdn.pwskills.com/assets/uploads/course-thumbnail/db48ccaa-8ca6-4592-8d18-4144cbe9651d.jpeg" alt="Circular" class="circular-image">
# </body>
# </html>

# %% [markdown]
# QUES-5->Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
# align center to the page, below the heading have an image of Google fonts and a paragraph about Google
# fonts in font “Montserrat” paragraph font style should be“montserrat” font?<BR><BR><BR>
# ANS=><br><br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Google Fonts Blog</title>
#     <link href="https://fonts.googleapis.com/css2?family=Montserrat&family=Oswald&display=swap"/>
#     <style>
#         body{
#             margin:0;
#             padding:20px;
#             font-family:'Montserrat',sam-serif;
#             display:flex;
#             flex-direction:column;
#             align-items: center;
#             text-align: center;
#         }
#         h1{
#             font-family:'Oswald',sans-serif;
#             font-size:2.5rem;
#             margin-bottom:20px;
#         }
#         img{
#             max-width: 100%;
#             height:auto;
#             margin-bottom: 20px;
#         }
#         p{
#             max-width: 800px;
#             font-size:1.1rem;
#             line-height: 1.6;
#         }
#     </style>
# </head>
# <body>
#     <h1>Discover the Power of Google Fonts</h1>
#     <img src="https://images.seeklogo.com/logo-png/39/2/google-fonts-logo-png_seeklogo-399629.png" alt="Google Fonts Logo" />
#     <p>
#         google fonts is a free and open source collection of web fonts offerd by google. it provides a huge library of high-quality,customizable fonts that are very easy to integrate into websites.whether you're desiging for readibility or visual impact,google fonts offers a diverse selection to suit ay style.
#     </p>
# </body>
# </html>

# %% [markdown]
# QUES-6-> Create a simple website as mentioned in the below image. You can get the assets by visiting https://
# pwskills.com/about-us?
# <br><br>
# ANS=>
# <br><br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>About -Us-Pwskills</title>
#     <style>
#         body{
#             margin:0;
#             font-family:arial,sans-serif;
#             background-color: #fff;
#             color:#333;
#             padding:20px;
#             text-align: center;
#         }
#         .container{
#             max-width: 900px;
#             margin:0 auto;
#         }
#         h1{
#             font-size:1.1rem;
#             line-height :1.6em;
#             margin-bottom: 30px;
#         }
#         img{
#             width: 100%;
#             border-radius: 12px;
#             max-height:auto;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>About Us</h1>
#         <P>
#             PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It". We aim to do this by providing exceptional up skilling courses at affordable rates, while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.
#           </P>
#           <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5E0Re3InX1JpiRmz4pvheoDB0rGoXAfe8oQ&s" alt="PW SKILLS CROWD">
#         </div>
# </body>
# </html>

# %% [markdown]
# QUES-7->Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
# default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output?<br><br>
# ANS=>
# <br><br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web development</title>
#     <style>
#         body{
#             font-family:Arial, Helvetica, sans-serif;
#             display:flex;
#             justify-content: center;
#             align-items: center;
#             height:100vh;
#             background-color: #f2f2f2;
#             margin:0;
#             padding:40px;
#         }
#         .card{
#             width: 350px;
#             border:1px solid #333;
#             border-radius: 12px;
#             overflow: hidden;
#             box-shadow: 0 4px 8 px rgba(0,0,0,0.2);
#             transition: opacity 0.4s ease;
#             opacity: 0.5;
#         }
#         .card:hover{
#             opacity: 1;
#         }
#         .card img{
#             width: 100%;
#             display: block;
#         }
#         .card text{
#             background-color: #a4f3d3;
#             padding:10px;
#             text-align:center;
#             font-weight:bold;
#             color:#000;
#         }
#         .card-footer {
#       background-color: #a2f4d3;
#       padding: 12px;
#       text-align: center;
#       font-weight: bold;
#       font-size: 1rem;
#     }
#
#     .card-footer span {
#       color: #007f00;
#     }
#     </style>
# </head>
# <body>
#     <div class="card">
#         <img src="https://s3.ap-south-1.amazonaws.com/cdn.pwskills.com/assets/uploads/course-thumbnail/a53e2c67-35d4-46f8-8fc9-0d6327835a81.jpeg" alt="Web Development Course" />
#         <div class="card-footer">
#             Course Name:<span >pw skills web development</span>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# QUES-8->Create a simple list of items as mentioned in the below image?<br><br>
# ANS=><BR><BR><!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Requirements</title>
#     <style>
#         body{
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height:100vh;
#             background-color: #fff;
#             margin:0;
#             font-family: Georgia, 'Times New Roman', Times, serif;
#         }
#         .box{
#             border:2px solid black;
#             padding:30px;
#             max-width: 600px;
#         }
#         h1{
#             font-size: 2.2rem;
#             margin-bottom: 20px;
#         }
#         ol{
#             list-style-type:lower-roman;
#             font-size:1.1rem;
#             padding-left:30px;
#         }
#         li{
#             margin-bottom: 10px;
#         }
#     </style>
# </head>
# <body>
#     <div class="box">
#         <h1><b>REQURIMENTS</b></h1>
#         <ol>
#             <li> sysytem with minimum i3 processor or better.</li>
#             <li>at least 4gb ram</li>
#             <li>working internet connection</li>
#             <li>dedication to learn</li>
#         </ol>
#     </div>
# </body>
# </html>
